# %%
import numpy as np
import pandas as pd
import seaborn as sns

# %%
data = pd.read_csv("hotel_bookings.csv")

# %%
data.shape
# Out:
# (498, 32)

# %%
data.head()
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  ...  deposit_type  \
# 0                        0                     0       2  ...    No Deposit
# ...

# %%
data.tail()
# Out:
#             hotel  is_canceled  lead_time  arrival_date_year  \
# 493  Resort Hotel            0         99               2015
# 494  Resort Hotel            0         25               2015
# 495  Resort Hotel            0         92               2015
# 496  Resort Hotel            0         91               2015
# 497  Resort Hotel            0         38               2015
#
#     arrival_date_month  arrival_date_week_number  arrival_date_day_of_month  \
# 493               July                        29                         17
# 494               July                        29                         17
# 495               July                        29                         17
# 496               July                        29                         17
# 497               July                        29                         17
#
#      stays_in_weekend_nights  stays_in_week_nights  adults  ...  deposit_type  \
# ...

# %%
pd.set_option('display.max_columns', None)

# %%
data.tail()
# Out:
#             hotel  is_canceled  lead_time  arrival_date_year  \
# 493  Resort Hotel            0         99               2015
# 494  Resort Hotel            0         25               2015
# 495  Resort Hotel            0         92               2015
# 496  Resort Hotel            0         91               2015
# 497  Resort Hotel            0         38               2015
#
#     arrival_date_month  arrival_date_week_number  arrival_date_day_of_month  \
# 493               July                        29                         17
# 494               July                        29                         17
# 495               July                        29                         17
# 496               July                        29                         17
# 497               July                        29                         17
#
#      stays_in_weekend_nights  stays_in_week_nights  adults  children  babies  \
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 498 entries, 0 to 497
# Data columns (total 32 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   hotel                           498 non-null    object
#  1   is_canceled                     498 non-null    int64
#  2   lead_time                       498 non-null    int64
#  3   arrival_date_year               498 non-null    int64
#  4   arrival_date_month              498 non-null    object
#  5   arrival_date_week_number        498 non-null    int64
#  6   arrival_date_day_of_month       498 non-null    int64
#  7   stays_in_weekend_nights         498 non-null    int64
#  8   stays_in_week_nights            498 non-null    int64
#  9   adults                          498 non-null    int64
#  10  children                        498 non-null    int64
#  11  babies                          498 non-null    int64
# ...

# %%
## get the list of all the columns
data.columns
# Out:
# Index(['hotel', 'is_canceled', 'lead_time', 'arrival_date_year',
#        'arrival_date_month', 'arrival_date_week_number',
#        'arrival_date_day_of_month', 'stays_in_weekend_nights',
#        'stays_in_week_nights', 'adults', 'children', 'babies', 'meal',
#        'country', 'market_segment', 'distribution_channel',
#        'is_repeated_guest', 'previous_cancellations',
#        'previous_bookings_not_canceled', 'reserved_room_type',
#        'assigned_room_type', 'booking_changes', 'deposit_type', 'agent',
#        'company', 'days_in_waiting_list', 'customer_type', 'adr',
#        'required_car_parking_spaces', 'total_of_special_requests',
#        'reservation_status', 'Unnamed: 31'],
#       dtype='object')

# %%
for column in data.columns:
    if data[column].dtype == "object":
        print(column)
# Out:
# hotel
# arrival_date_month
# meal
# country
# market_segment
# distribution_channel
# reserved_room_type
# assigned_room_type
# deposit_type
# customer_type
# reservation_status

# %%
## missing Values
for column in data.columns:
    if data[column].isna().sum() > 0:
        print(f"{column} has {data[column].isna().sum()} missing values")
# Out:
# agent has 45 missing values
# company has 491 missing values
# Unnamed: 31 has 498 missing values

# %%
data.describe()
# Out:
#        is_canceled   lead_time  arrival_date_year  arrival_date_week_number  \
# count   498.000000  498.000000              498.0                498.000000
# mean      0.204819   60.941767             2015.0                 28.120482
# std       0.403975   63.848370                0.0                  0.795828
# min       0.000000    0.000000             2015.0                 27.000000
# 25%       0.000000   18.250000             2015.0                 27.000000
# 50%       0.000000   54.000000             2015.0                 28.000000
# 75%       0.000000   88.000000             2015.0                 29.000000
# max       1.000000  737.000000             2015.0                 29.000000
#
#        arrival_date_day_of_month  stays_in_weekend_nights  \
# count                 498.000000               498.000000
# mean                    8.987952                 1.317269
# std                     5.095058                 1.155750
# ...

# %%
import random
num = random.choices(range(1,100), k = 10)

# min  = 1
# max = 9
# 50% = 5
# 25% = 3
# 75% = 7

# %%
num.sort()
num
# Out:
# [11, 13, 18, 26, 32, 66, 73, 81, 86, 92]

# %%
min = 11
25% = 18
50% = (32,66) (32+66)/2, = 49
75% = 81
max = 92
# Out:
#   Cell In[31], line 2
#     50% = (32,66) (32+66)/2,
#         ^
# SyntaxError: invalid syntax

# %%
(32+66)/2
# Out:
# 49.0

# %% [markdown]
# # Observations
#
# - 498 Entries
# - 32 columns
# - unknown column called Unnamed: 31
# - arrival_date_year only have 2015
# - columns with only zero:
#     - is_repeated_guest
#     - previous_cancellations
#     - previous_bookings_not_canceled
# - columns with one cat
#     - hotel
#     - arrival_date_month
#     - country
#     - deposit_type
# - **Categorical**
#     - hotel
#     - arrival_date_month
#     - meal
#     - country
#     - market_segment
#     - distribution_channel
#     - reserved_room_type
#     - assigned_room_type
#     - deposit_type
#     - customer_type
#     - reservation_status
# - **Missing Values**
#     - agent has 45 missing values
#     - company has 491 missing values
#     - Unnamed: 31 has 498 missing values
# - **Abnomalities**
#     - lead_time
#     - stays_in_week_nights
#     - agent
#     - company
#     - adr
#     - children

# %%
import matplotlib.pyplot as plt
for column in data.columns:
    if data[column].dtype == "object":
        sns.countplot(x = column, data = data)
        # plt.show()

# %%
columns_to_delete = []
for column in data.columns:
    if data[column].dtype == "object":
        if data[column].nunique() == 1:
            columns_to_delete.append(column)
    else:
        if data[column].std() == 0:
            columns_to_delete.append(column)

# %%
columns_to_delete
# Out:
# ['hotel',
#  'arrival_date_year',
#  'arrival_date_month',
#  'country',
#  'is_repeated_guest',
#  'previous_cancellations',
#  'previous_bookings_not_canceled',
#  'deposit_type',
#  'days_in_waiting_list']

# %%
data.drop(columns_to_delete, axis = 1, inplace = True)

# %%
data.shape
# Out:
# (498, 23)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 498 entries, 0 to 497
# Data columns (total 23 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   is_canceled                  498 non-null    int64
#  1   lead_time                    498 non-null    int64
#  2   arrival_date_week_number     498 non-null    int64
#  3   arrival_date_day_of_month    498 non-null    int64
#  4   stays_in_weekend_nights      498 non-null    int64
#  5   stays_in_week_nights         498 non-null    int64
#  6   adults                       498 non-null    int64
#  7   children                     498 non-null    int64
#  8   babies                       498 non-null    int64
#  9   meal                         498 non-null    object
#  10  market_segment               498 non-null    object
#  11  distribution_channel         498 non-null    object
#  12  reserved_room_type           498 non-null    object
# ...

# %%
data.columns
# Out:
# Index(['is_canceled', 'lead_time', 'arrival_date_week_number',
#        'arrival_date_day_of_month', 'stays_in_weekend_nights',
#        'stays_in_week_nights', 'adults', 'children', 'babies', 'meal',
#        'market_segment', 'distribution_channel', 'reserved_room_type',
#        'assigned_room_type', 'booking_changes', 'agent', 'company',
#        'customer_type', 'adr', 'required_car_parking_spaces',
#        'total_of_special_requests', 'reservation_status', 'Unnamed: 31'],
#       dtype='object')

# %%
del data["company"]
del data["Unnamed: 31"]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 498 entries, 0 to 497
# Data columns (total 21 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   is_canceled                  498 non-null    int64
#  1   lead_time                    498 non-null    int64
#  2   arrival_date_week_number     498 non-null    int64
#  3   arrival_date_day_of_month    498 non-null    int64
#  4   stays_in_weekend_nights      498 non-null    int64
#  5   stays_in_week_nights         498 non-null    int64
#  6   adults                       498 non-null    int64
#  7   children                     498 non-null    int64
#  8   babies                       498 non-null    int64
#  9   meal                         498 non-null    object
#  10  market_segment               498 non-null    object
#  11  distribution_channel         498 non-null    object
#  12  reserved_room_type           498 non-null    object
# ...

# %% [markdown]
# - **Abnomalities**
#     - lead_time
#     - stays_in_week_nights
#     - agent
#     - company
#     - adr
#     - children
# - **outlier**
#     - stays_in_week_nights
#     - lead_time
#     - children

# %%
data.describe()
# Out:
#        is_canceled   lead_time  arrival_date_week_number  \
# count   498.000000  498.000000                498.000000
# mean      0.204819   60.941767                 28.120482
# std       0.403975   63.848370                  0.795828
# min       0.000000    0.000000                 27.000000
# 25%       0.000000   18.250000                 27.000000
# 50%       0.000000   54.000000                 28.000000
# 75%       0.000000   88.000000                 29.000000
# max       1.000000  737.000000                 29.000000
#
#        arrival_date_day_of_month  stays_in_weekend_nights  \
# count                 498.000000               498.000000
# mean                    8.987952                 1.317269
# std                     5.095058                 1.155750
# min                     1.000000                 0.000000
# 25%                     4.000000                 0.000000
# 50%                    10.000000                 1.000000
# ...

# %%
sns.scatterplot(x ="stays_in_week_nights", y = "arrival_date_day_of_month", data = data)
# Out:
# <Axes: xlabel='stays_in_week_nights', ylabel='arrival_date_day_of_month'>

# %%
sns.scatterplot(x ="lead_time", y = "arrival_date_day_of_month", data = data)
# Out:
# <Axes: xlabel='lead_time', ylabel='arrival_date_day_of_month'>

# %%
sns.jointplot(x ="agent", y = "arrival_date_day_of_month", data = data)

# %%
sns.jointplot(x ="adr", y = "arrival_date_day_of_month", data = data)

# %%
sns.jointplot(x ="children", y = "adr", data = data)

# %%
data.isna().sum()
# Out:
# is_canceled                     0
# lead_time                       0
# arrival_date_week_number        0
# arrival_date_day_of_month       0
# stays_in_weekend_nights         0
# stays_in_week_nights            0
# adults                          0
# children                        0
# babies                          0
# meal                            0
# market_segment                  0
# distribution_channel            0
# reserved_room_type              0
# assigned_room_type              0
# booking_changes                 0
# agent                          45
# customer_type                   0
# adr                             0
# required_car_parking_spaces     0
# total_of_special_requests       0
# reservation_status              0
# dtype: int64

# %%
data.agent.describe()
# Out:
# count    453.000000
# mean     212.640177
# std       72.380270
# min        2.000000
# 25%      240.000000
# 50%      240.000000
# 75%      241.000000
# max      306.000000
# Name: agent, dtype: float64

# %%
data["agent"].median()
# Out:
# 240.0

# %%
data['agent'].fillna(data["agent"].median(), inplace=True)

# %%
data.isna().sum()
# Out:
# is_canceled                    0
# lead_time                      0
# arrival_date_week_number       0
# arrival_date_day_of_month      0
# stays_in_weekend_nights        0
# stays_in_week_nights           0
# adults                         0
# children                       0
# babies                         0
# meal                           0
# market_segment                 0
# distribution_channel           0
# reserved_room_type             0
# assigned_room_type             0
# booking_changes                0
# agent                          0
# customer_type                  0
# adr                            0
# required_car_parking_spaces    0
# total_of_special_requests      0
# reservation_status             0
# dtype: int64
